# %% [markdown]
# ## APIs
# get --> fetch data <br>
# post --> send data to API <br>
# put --> to update info <br>
# delete --> to delete info

# %%
import requests
# apiurl = "https://jsonplaceholder.typicode.com/posts"
# response = requests.get(apiurl)
# print(response.status_code)
# print(response.json())

# %%
import sqlite3
# if response.status_code == 200:
#     data = response.json()
#     print('Post ID','Title','Body',sep="\t\t\t\t\t")
#     for d in data:
#         print(d.get('id'),d.get('title')[:5],d.get('body')[:10],sep="\t\t\t\t\t")
#     with sqlite3.connect(r"C:\Users\Karan\Desktop\ids-python\python-programming\CS-Infotech\apidata.db") as con:
#         cmd = "insert into tbpost(id,title,desc) values(?,?,?)"
#         lst = []
#         for d in data:
#             lst.append((d.get('id'),d.get('title')[:5],d.get('body')[:10]))
#         con.executemany(cmd, lst)
#         con.commit()

# %%
apiurl = "https://jsonplaceholder.typicode.com/posts"
payload = {
    "id":102,
    "title":"Mytitle!",
    "body":"enfjkernfjerkogjtgjjrogj"   
    }
response = requests.post(apiurl,json=payload)
if response.status_code == 201:
    print("Successfully posted")
    print(response.json())
# Out:
# Successfully posted
# {'id': 101, 'title': 'Mytitle!', 'body': 'enfjkernfjerkogjtgjjrogj'}

# %%
import time
from rich.console import Console
import ipywidgets as widgets


def do_something_important():
    time.sleep(5.0)  # Simulates a long process

console = Console()
with console.status(
    "Please wait - solving global problems...", spinner="earth"
):
    do_something_important()

console.print("All fixed! :sunglasses:")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# All fixed! 😎

# %%
console.print("[yellow]Hi[/yellow] [green underline]World")
# Out:
# Hi World

# %%
from termcolor import colored

text = colored("Hello, World!", "red")
print(text)
# Out:
# Hello, World!

# %%
import ipywidgets as widgets

from ipywidgets import IntSlider
import IPython.display as display

slider = IntSlider(value=5, min=0, max=10)
display.display(slider)
# Out:
# IntSlider(value=5, max=10)

# %%
import pandas as pd
import yfinance as yf
idk = yf.download(tickers="AAPL", interval="15m", start="2026-03-31", end="2026-04-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_values = []
for i in idk.iloc[:, 0:1]:
    for j in idk[i]:
        aapl_values.append(j)
print(aapl_values)
#min_val = min(aapl_values)
#max_val = max(aapl_values)
# Out:
# [247.82000732421875, 248.81500244140625, 248.50999450683594, 248.94009399414062, 247.61000061035156, 247.32000732421875, 248.3800048828125, 248.42999267578125, 248.63499450683594, 248.61000061035156, 249.46499633789062, 250.33999633789062, 251.77000427246094, 253.1300048828125, 253.25, 253.22500610351562, 252.58009338378906, 252.5399932861328, 252.8000030517578, 253.1300048828125, 253.39999389648438, 253.7550048828125, 253.89500427246094, 253.6699981689453, 253.9499969482422, 253.7899932861328]

# %%
scaled_aapl = []
for i in aapl_values:
    min_val = min(aapl_values)
    max_val = max(aapl_values)
    scale = i - min_val
    range_ = max_val - min_val
    pos_ = scale/range_
    map_ = pos_ * 19
    new_y = round(19 - map_)
    scaled_aapl.append(new_y)
print(scaled_aapl)
len(scaled_aapl)
# Out:
# [18, 15, 16, 14, 18, 19, 16, 16, 15, 15, 13, 10, 6, 2, 2, 2, 4, 4, 3, 2, 2, 1, 0, 1, 0, 0]
# 26

# %%
idk.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 26 entries, 2026-03-31 13:30:00+00:00 to 2026-03-31 19:45:00+00:00
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   26 non-null     float64
#  1   (High, AAPL)    26 non-null     float64
#  2   (Low, AAPL)     26 non-null     float64
#  3   (Open, AAPL)    26 non-null     float64
#  4   (Volume, AAPL)  26 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 1.2 KB

# %%
idk.iloc[:, 0:1]
# Out:
# Price                           Close
# Ticker                           AAPL
# Datetime
# 2026-03-31 13:30:00+00:00  247.820007
# 2026-03-31 13:45:00+00:00  248.815002
# 2026-03-31 14:00:00+00:00  248.509995
# 2026-03-31 14:15:00+00:00  248.940094
# 2026-03-31 14:30:00+00:00  247.610001
# 2026-03-31 14:45:00+00:00  247.320007
# 2026-03-31 15:00:00+00:00  248.380005
# 2026-03-31 15:15:00+00:00  248.429993
# 2026-03-31 15:30:00+00:00  248.634995
# 2026-03-31 15:45:00+00:00  248.610001
# 2026-03-31 16:00:00+00:00  249.464996
# 2026-03-31 16:15:00+00:00  250.339996
# 2026-03-31 16:30:00+00:00  251.770004
# 2026-03-31 16:45:00+00:00  253.130005
# 2026-03-31 17:00:00+00:00  253.250000
# 2026-03-31 17:15:00+00:00  253.225006
# 2026-03-31 17:30:00+00:00  252.580093
# 2026-03-31 17:45:00+00:00  252.539993
# 2026-03-31 18:00:00+00:00  252.800003
# 2026-03-31 18:15:00+00:00  253.130005
# 2026-03-31 18:30:00+00:00  253.399994
# 2026-03-31 18:45:00+00:00  253.755005
# 2026-03-31 19:00:00+00:00  253.895004
# 2026-03-31 19:15:00+00:00  253.669998
# 2026-03-31 19:30:00+00:00  253.949997
# 2026-03-31 19:45:00+00:00  253.789993

# %%
idklol = yf.download(tickers="MSFT", interval="15m", period="1d")
idklol
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                           Close        High         Low        Open  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Datetime
# 2026-04-02 13:30:00+00:00  364.859985  367.609985  364.149994  367.204987
# 2026-04-02 13:45:00+00:00  365.929993  366.179993  364.609985  364.855011
# 2026-04-02 14:00:00+00:00  366.820007  366.890015  365.040009  365.980011
# 2026-04-02 14:15:00+00:00  366.704987  367.200012  366.029999  366.829987
# 2026-04-02 14:30:00+00:00  370.040100  371.058594  366.549988  366.690002
# 2026-04-02 14:45:00+00:00  369.999298  370.579987  368.519989  370.040009
# 2026-04-02 15:00:00+00:00  370.700012  371.220001  369.390106  369.920013
# 2026-04-02 15:15:00+00:00  370.809998  371.070007  369.760010  370.720001
# 2026-04-02 15:30:00+00:00  371.144989  371.299988  370.309998  370.850006
# 2026-04-02 15:45:00+00:00  370.299988  371.180115  369.540009  371.144989
# 2026-04-02 16:00:00+00:00  369.901398  370.500000  369.410004  370.339996
# 2026-04-02 16:15:00+00:00  369.747101  370.119995  369.394989  369.869995
# 2026-04-02 16:30:00+00:00  371.149994  371.390015  369.464996  369.734985
# 2026-04-02 16:45:00+00:00  371.019989  371.679993  370.959991  371.179993
# 2026-04-02 17:00:00+00:00  371.318695  371.349915  370.484985  371.040009
# 2026-04-02 17:15:00+00:00  371.579987  371.890015  371.280090  371.299988
# 2026-04-02 17:30:00+00:00  371.540009  371.839996  371.299988  371.600006
# 2026-04-02 17:45:00+00:00  370.859894  371.609985  370.510010  371.549988
# 2026-04-02 18:00:00+00:00  371.299988  371.678986  370.829987  370.875000
# 2026-04-02 18:15:00+00:00  371.049408  371.545013  370.940002  371.309998
# 2026-04-02 18:30:00+00:00  371.609711  371.609985  370.920013  371.019989
# 2026-04-02 18:45:00+00:00  371.359985  371.690002  371.079987  371.589996
# 2026-04-02 19:00:00+00:00  371.200012  371.540009  370.850006  371.380005
# 2026-04-02 19:15:00+00:00  372.579895  373.200012  370.725006  371.195007
# 2026-04-02 19:30:00+00:00  372.269989  373.160004  372.079987  372.554993
# 2026-04-02 19:45:00+00:00  373.500000  373.600006  372.010101  372.250000
#
# Price                       Volume
# Ticker                        MSFT
# Datetime
# 2026-04-02 13:30:00+00:00  2370501
# 2026-04-02 13:45:00+00:00   884564
# 2026-04-02 14:00:00+00:00   788305
# 2026-04-02 14:15:00+00:00  1100120
# 2026-04-02 14:30:00+00:00  1262197
# 2026-04-02 14:45:00+00:00   662173
# 2026-04-02 15:00:00+00:00   522298
# 2026-04-02 15:15:00+00:00   574103
# 2026-04-02 15:30:00+00:00   703858
# 2026-04-02 15:45:00+00:00   415377
# 2026-04-02 16:00:00+00:00   296222
# 2026-04-02 16:15:00+00:00   361624
# 2026-04-02 16:30:00+00:00   384030
# 2026-04-02 16:45:00+00:00   382024
# 2026-04-02 17:00:00+00:00   649464
# 2026-04-02 17:15:00+00:00   389018
# 2026-04-02 17:30:00+00:00   372697
# 2026-04-02 17:45:00+00:00   406648
# 2026-04-02 18:00:00+00:00   373212
# 2026-04-02 18:15:00+00:00   324918
# 2026-04-02 18:30:00+00:00   430660
# 2026-04-02 18:45:00+00:00   405430
# 2026-04-02 19:00:00+00:00   518976
# 2026-04-02 19:15:00+00:00  1429131
# 2026-04-02 19:30:00+00:00  1186696
# 2026-04-02 19:45:00+00:00  1701010

# %%
for k in range(16,10-1,-1):
    print(k)
# Out:
# 16
# 15
# 14
# 13
# 12
# 11
# 10

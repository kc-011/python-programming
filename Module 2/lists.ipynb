# %% [markdown]
# HI

# %% [markdown]
# **Yo**

# %%
list1 = []
for i in range(10):
    list1 += [i-5]
print(list1)
# Out:
# [-5, -4, -3, -2, -1, 0, 1, 2, 3, 4]

# %%
a = [1,2,3]
list2 = [0]
print(a+list2)
# Out:
# [1, 2, 3, 0]

# %% [markdown]
# *List Creation*

# %%
list3 = list("hey")
print(list3)
# Out:
# ['h', 'e', 'y']

# %%
def find_largest(numbers):
    min_value = 0
    for i in range(len(numbers)): #can also do num in numbers ?!
        if numbers[i] > min_value:
            min_value = numbers[i]
    return min_value
print(find_largest([1,5,6,2]))
# Out:
# 6

# %%
print(list(range(1, 0,-1)))
# Out:
# [1]
